# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
#Categories=['199.4', '197.5', '196.5', '195.5', '193.4', '192.1', '190.9', '190.2', '188.1', '186', '183.2', '182.7', '181.4', '179.3', '178.8', '177.5', '174.1', '171.8', '168', '167', '165', '164.4', '163.3', '162.2', '161.65', '161.1', '160.1', '158.4', '156.9', '154.2', '147.85', '147', '146.05', '143.9', '142.6', '141.45', '140.3', '139.1', '137.95', '137', '135.7', '134', '133.2', '130.6', '130.2', '121.25', '127.9', '126.3', '124.65', '123.9', '122.3', '119.85', '119.7', '118', '116.1', '114.7', '113.3', '112.5', '110.5', '109', '107.6', '106.8', '105', '104.3', '103.2', '101.5', '99.9', '98', '97.25', '95.9', '94.2', '93.4', '92.3', '91.3', '89', '88.4', '87', '85.1', '84.7', '83.25', '80.7', '81.85', '79.9', '78.6', '76.95', '76.35', '75.45', '74.45', '73.3', '67.75', '70', '71', '71.55', '68.3', '67', '66.25', '64.8', '63.6', '61.3', '61', '57.3', '60.05', '58.8', '57.8', '55.7', '54.85', '53.05', '52.1', '56.4', '53.8', '51.15', '50.3', '48.95', '47.5', '46.6', '45.35', '44.5', '43', '41.6', '40.5', '38.5', '39.4', '37.4', '36', '34.7', '32.1', '33.4', '29.6', '30.9', '28.4', '26.7', '16.9', '24.4', '24.85', '23.5', '22.2', '20.3', '18.8', '16.2', '14.1', '12.95', '12.05', '11.2', '10.25', '0', '9.45', '8.1', '7.2', '6.2', '2.6', '5.1', '3.65', '1.05']
Categories=['121.25', '127.9', '126.3', '124.65', '123.9', '122.3', '119.85', '119.7', '118', '116.1', '114.7', '113.3', '112.5', '110.5', '109', '107.6', '106.8', '105', '104.3', '103.2', '101.5', '99.9', '98', '97.25', '95.9', '94.2', '93.4', '92.3', '91.3', '89', '88.4', '87', '85.1', '84.7', '83.25', '80.7', '81.85', '79.9', '78.6', '76.95', '76.35', '75.45', '74.45', '73.3', '67.75', '70', '71', '71.55', '68.3', '67', '66.25', '64.8', '63.6', '61.3', '61', '57.3', '60.05', '58.8', '57.8', '55.7', '54.85', '53.05', '52.1', '56.4', '53.8', '51.15', '50.3', '48.95', '47.5', '46.6', '45.35', '44.5', '43', '41.6', '40.5', '38.5', '39.4', '37.4', '36', '34.7', '32.1', '33.4', '29.6', '30.9', '28.4', '26.7', '16.9', '24.4', '24.85', '23.5', '22.2', '20.3', '18.8', '16.2', '14.1', '12.95', '12.05', '11.2', '10.25', '0', '9.45', '8.1', '7.2', '6.2', '2.6', '5.1', '3.65', '1.05']
flat_data_arr=[] #input array
target_arr = [] #output array

#FULL DATA
#datadir='/content/gdrive/MyDrive/Test1/DATA/SATURATION/0deg_LED_saturation'
#datadir='/content/gdrive/MyDrive/Test1/DATA/SATURATION/open_noLED_png_saturation' 

#Dataset_128
#datadir='/content/gdrive/MyDrive/Hasil_Train/Dataset_128/0deg_LED_saturation'
#datadir='/content/gdrive/MyDrive/Hasil_Train/Dataset_128/open_noLED_png_saturation'
#datadir='/content/gdrive/MyDrive/Hasil_Train/Dataset_128/0deg_LED_LBP_blurfirst'
datadir='/content/gdrive/MyDrive/Hasil_Train/Dataset_128/open_noLED_png_LBP_blurfirst'

#path which contains all the categories of images
for i in Categories:
    
    print(f'loading... category : {i}')
    path=os.path.join(datadir,i)
    for img in os.listdir(path):
        img_array=imread(os.path.join(path,img))
        img_resized=resize(img_array,(224,224,1))
        flat_data_arr.append(img_resized.flatten())
        target_arr.append(i)
    print(f'loaded category:{i} successfully')
flat_data=np.array(flat_data_arr, dtype=np.float32)
target=np.array(target_arr, dtype=np.float32)
df=pd.DataFrame(flat_data) #dataframe
df['Target']=target
x=df.iloc[:,:-1] #input data 
y=df.iloc[:,-1] #output data
# Out:
# loading... category : 121.25
# loaded category:121.25 successfully
# loading... category : 127.9
# loaded category:127.9 successfully
# loading... category : 126.3
# loaded category:126.3 successfully
# loading... category : 124.65
# loaded category:124.65 successfully
# loading... category : 123.9
# loaded category:123.9 successfully
# loading... category : 122.3
# loaded category:122.3 successfully
# loading... category : 119.85
# loaded category:119.85 successfully
# loading... category : 119.7
# loaded category:119.7 successfully
# loading... category : 118
# loaded category:118 successfully
# loading... category : 116.1
# loaded category:116.1 successfully
# loading... category : 114.7
# loaded category:114.7 successfully
# loading... category : 113.3
# loaded category:113.3 successfully
# loading... category : 112.5
# loaded category:112.5 successfully
# loading... category : 110.5
# loaded category:110.5 successfully
# loading... category : 109
# ...

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
images_sc = scale.fit_transform(df)
images_sc = pd.DataFrame(images_sc, columns=df.columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)
print('Splitted Successfully')
# Out:
# Splitted Successfully

# %%
from sklearn.svm import SVR
#regressor = SVR(C=0.1, epsilon=0.1, kernel='linear')
#regressor = SVR(C=10, epsilon=1, kernel='linear')
#regressor = SVR(C=0.01, epsilon=0.001, kernel='linear')
regressor = SVR(C=0.1, epsilon=0.001, kernel='linear')

regressor.fit(x_train, y_train)
# Out:
# SVR(C=0.1, epsilon=0.001, kernel='linear')

# %%
train_pred = regressor.predict(x_train)
train_true = y_train
train_residuals = train_true - train_pred

test_pred = regressor.predict(x_test)
test_true = y_test
test_residuals = test_true - test_pred

# %%
from sklearn.metrics import r2_score as r2
r2_train = r2(train_true,train_pred)
r2_test = r2(test_true,test_pred)
print(format(r2_train,".3f"))
print(format(r2_test,".3f"))
# Out:
# 1.000
# 0.759

# %%
pd.DataFrame(test_residuals).to_csv("test_residuals_90deg_lbp.csv")

# %% [markdown]
# ABAIKAN

# %%
pd.DataFrame(test_pred).to_csv("test_pred_90deg_sat.csv")
pd.DataFrame(y_test).to_csv("y_test_90deg_sat.csv")
