# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os
import os.path

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
os.chdir('..')
image_dir = Path(r'content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0deg_LED_resized')

# %%
filepaths = pd.Series(list(image_dir.glob(r'**/*.png')), name='Filepath').astype(str)
filepaths
# Out:
# 0      content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# 1      content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# 2      content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# 3      content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# 4      content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
#                              ...
# 766    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# 767    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# 768    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# 769    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# 770    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...
# Name: Filepath, Length: 771, dtype: object

# %%
filepaths.apply(lambda x: os.path.split(os.path.split(x)[0][1]))
# Out:
# 0      (, o)
# 1      (, o)
# 2      (, o)
# 3      (, o)
# 4      (, o)
#        ...
# 766    (, o)
# 767    (, o)
# 768    (, o)
# 769    (, o)
# 770    (, o)
# Name: Filepath, Length: 771, dtype: object

# %%
turbid = pd.Series(filepaths.apply(lambda x: os.path.split(os.path.split(x)[0])[1]), name='Turbidity').astype(float)
turbid
# Out:
# 0      101.5
# 1      101.5
# 2      101.5
# 3      101.5
# 4      101.5
#        ...
# 766      0.0
# 767      0.0
# 768      0.0
# 769      0.0
# 770      0.0
# Name: Turbidity, Length: 771, dtype: float64

# %%
images = pd.concat([filepaths, turbid], axis=1).sample(frac=1.0, random_state=1).reset_index(drop=True)
images
# Out:
#                                               Filepath  Turbidity
# 0    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...     161.10
# 1    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...     199.40
# 2    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...      16.20
# 3    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...     190.20
# 4    content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...      89.00
# ..                                                 ...        ...
# 766  content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...      24.85
# 767  content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...       0.00
# 768  content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...     106.80
# 769  content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...     156.90
# 770  content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0...     119.70
#
# [771 rows x 2 columns]

# %% [markdown]
# Optional

# %%
def fix_path(x):
    return "./" + x

images['Filepath'] = images['Filepath'].apply(fix_path)
#images['Filepath'].replace(to_replace='\\', value='/', inplace=True, regex=True)

# %%
images.to_csv(r'content/gdrive/MyDrive/Test1/DATA/SIAP_TRAIN/0deg_LED_resized.csv', index=False)
